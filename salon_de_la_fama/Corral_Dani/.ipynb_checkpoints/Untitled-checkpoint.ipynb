# %%
import pandas as pd
data = pd.read_csv("Characters.csv", sep=';') 
data
# Out:
#       Id                                     Name  Gender  \
# 0      1                       Harry James Potter    Male
# 1      2              Ron (Ronald) Bilius Weasley    Male
# 2      3                    Hermione Jean Granger  Female
# 3      4  Albus Percival Wulfric Brian Dumbledore    Male
# 4      5                            Rubeus Hagrid    Male
# ..   ...                                      ...     ...
# 137  138                      Gellert Grindelwald    Male
# 138  139                                    Dobby    Male
# 139  140                          Madame Rosmerta  Female
# 140  141                                      Bem    Male
# 141  142                             Rita Skeeter  Female
#
#                                                    Job           House  \
# 0                                              Student      Gryffindor
# 1                                              Student      Gryffindor
# ...

# %%
'not applicable'
house = data['House'].fillna("Unknown")
house
#data[data['House'].isnull()]
# Out:
# 0          Gryffindor
# 1          Gryffindor
# 2          Gryffindor
# 3          Gryffindor
# 4          Gryffindor
#             ...
# 137           Unknown
# 138    Not applicable
# 139           Unknown
# 140        Gryffindor
# 141           Unknown
# Name: House, Length: 142, dtype: object

# %%
data[data['Patronus'].isnull()]
# Out:
#     Id                    Name  Gender  \
# 9   10             Dean Thomas    Male
# 13  14            Sirius Black    Male
# 16  17  Percy Ignatius Weasley    Male
# 17  18  (Bill) William Weasley    Male
# 18  19         Charles Weasley    Male
# 19  20              Lee Jordan    Male
# 20  21             Oliver Wood    Male
# 21  22        Angelina Johnson  Female
# 22  23              Katie Bell  Female
# 23  24          Alicia Spinnet  Female
# 24  25          Lavender Brown  Female
# 25  26           Parvati Patil  Female
# 26  27            Romilda Vane  Female
# 27  28           Colin Creevey    Male
# 28  29         Cormac McLaggen    Male
#
#                                                   Job       House  \
# 9                                             Student  Gryffindor
# 13                                                  -  Gryffindor
# 16  Student|Prefect|Personal assistant to Barty Cr...  Gryffindor
# ...
